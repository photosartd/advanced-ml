# %% [markdown]
# # Продвинутое машинное обучение
# # Домашнее задание 3

# %% [markdown]
# Третье домашнее задание посвящено достаточно простой, но, надеюсь, интересной задаче, в которой потребуется творчески применить методы сэмплирования. Как и раньше, в качестве решения ожидается ссылка на jupyter-ноутбук на вашем github (или публичный, или с доступом для snikolenko); ссылку обязательно нужно прислать в виде сданного домашнего задания на портале Академии. Как всегда, любые комментарии, новые идеи и рассуждения на тему категорически приветствуются. <br><br>
# В этом небольшом домашнем задании мы попробуем улучшить метод Шерлока Холмса. Как известно, в рассказе The Adventure of the Dancing Men великий сыщик расшифровал загадочные письмена, которые выглядели примерно так:

# %% [markdown]
# Пользовался он для этого так называемым частотным методом: смотрел, какие буквы чаще встречаются в зашифрованных текстах, и пытался подставить буквы в соответствии с частотной таблицей: E — самая частая и так далее. <br><br>
# В этом задании мы будем разрабатывать более современный и продвинутый вариант такого частотного метода. В качестве корпусов текстов для подсчётов частот можете взять что угодно, но для удобства вот вам “Война и мир” по-русски и по-английски:

# %%
war_and_peace = open("data/WarAndPeaceEng.txt", "r").read().replace('\n', '')

# %% [markdown]
# ### Imports

# %%
import numpy as np
from nltk.tokenize import RegexpTokenizer
from collections import Counter, defaultdict

# %% [markdown]
# ## Часть 1

# %% [markdown]
# Реализуйте базовый частотный метод по Шерлоку Холмсу: <br>
# - подсчитайте частоты букв по корпусам (пунктуацию и капитализацию можно просто опустить, а вот пробелы лучше оставить);
# - возьмите какие-нибудь тестовые тексты (нужно взять по меньшей мере 2-3 предложения, иначе вряд ли сработает), зашифруйте их посредством случайной перестановки символов;
# - расшифруйте их таким частотным методом.

# %% [markdown]
# ## Решение:

# %% [markdown]
# 1. Подсчет частот букв:

# %%
ENGLISH_ALPHABET = "abcdefghijklmnopqrstuvwxyz "

# %%
assert len(ENGLISH_ALPHABET) == 27

# %%
def tokenize_text(text, alphabet=ENGLISH_ALPHABET, tokenizer=RegexpTokenizer(pattern=r"\w+")):
    text = text.lower()
    text = "".join([s for s in text if s in alphabet])
    text = " ".join(tokenizer.tokenize(text))
    return text

# %%
def calculate_freqs(text):
    counts = Counter(text)
    counts = {
        s: count / len(text) for s, count in sorted(counts.items(), key=lambda x: x[1], reverse=True)
    }
    return counts

# %%
war_and_peace = tokenize_text(war_and_peace)

# %%
symbols_counts = calculate_freqs(war_and_peace)

# %% [markdown]
# 2. Текст английской версии Анны Карениной:

# %%
anna_karenina = "Everything was in confusion in the Oblonskys' house. The wife had discovered that the husband was carrying on an intrigue with a French girl, who had been a governess in their family, and she had announced to her husband that she could not go on living in the same house with him. This position of affairs had now lasted three days, and not only the husband and wife themselves, but all the members of their family and household, were painfully conscious of it."

# %%
anna_karenina = tokenize_text(anna_karenina.lower())

# %%
anna_karenina
# Out:
# 'everything was in confusion in the oblonskys house the wife had discovered that the husband was carrying on an intrigue with a french girl who had been a governess in their family and she had announced to her husband that she could not go on living in the same house with him this position of affairs had now lasted three days and not only the husband and wife themselves but all the members of their family and household were painfully conscious of it'

# %% [markdown]
# Сделаем рандомную перестановку символов:

# %%
english_alphabet_encoding = list(ENGLISH_ALPHABET)
np.random.shuffle(english_alphabet_encoding)
english_alphabet_encoding = "".join(english_alphabet_encoding)

# %%
english_alphabet_encoding
# Out:
# 'ilpqdou wrvecxmyhgsftzjkban'

# %%
def get_mappings(true_alphabet, shuffled_alphabet):
    mapping = {t: s for t, s in zip(true_alphabet, shuffled_alphabet)}
    inverse_mapping = {s: t for t, s in mapping.items()}
    return mapping, inverse_mapping

def map_to(s, mapping):
    new = []
    for symb in s:
        new.append(mapping[symb])
    return "".join(new)

# %%
mapping, inverse_mapping = get_mappings(ENGLISH_ALPHABET, english_alphabet_encoding)

# %%
anna_karenina_encoded = map_to(anna_karenina, mapping)

# %%
anna_karenina_encoded
# Out:
# 'dzdgbf wxunjisnwxnpmxotswmxnwxnf dnmlemxsvbsn mtsdnf dnjwodn iqnqwspmzdgdqnf ifnf dn tslixqnjisnpiggbwxunmxnixnwxfgwutdnjwf ninogdxp nuwgenj mn iqnlddxninumzdgxdssnwxnf dwgnoicwebnixqns dn iqnixxmtxpdqnfmn dgn tslixqnf ifns dnpmteqnxmfnumnmxnewzwxunwxnf dnsicdn mtsdnjwf n wcnf wsnymswfwmxnmoniooiwgsn iqnxmjneisfdqnf gddnqibsnixqnxmfnmxebnf dn tslixqnixqnjwodnf dcsdezdsnltfnieenf dncdcldgsnmonf dwgnoicwebnixqn mtsd meqnjdgdnyiwxoteebnpmxspwmtsnmonwf'

# %% [markdown]
# 3. Расшифруем текст

# %%
new_encoding_freqs = calculate_freqs(anna_karenina_encoded)

# %%
def decode(text, real_freqs, freqs):
    current_mapping = {}
    for real_f, f in zip(real_freqs.keys(), freqs.keys()):
        current_mapping[f] = real_f
    new_text = "".join([current_mapping[s] for s in text])
    return new_text

# %%
anna_karenina_decoded = decode(anna_karenina_encoded, symbols_counts, new_encoding_freqs)

# %%
anna_karenina_decoded
# Out:
# 'ebedwsaotg cnh ot fitmuhoit ot sae iylithkwh aiuhe sae come anr rohfibeder sans sae auhyntr cnh fnddwotg it nt otsdogue cosa n mdetfa godl cai anr yeet n gibedtehh ot saeod mnpolw ntr hae anr nttiutfer si aed auhyntr sans hae fiulr tis gi it lobotg ot sae hnpe aiuhe cosa aop saoh vihosoit im nmmnodh anr tic lnhser sadee rnwh ntr tis itlw sae auhyntr ntr come saephelbeh yus nll sae pepyedh im saeod mnpolw ntr aiuheailr cede vnotmullw fithfoiuh im os'

# %% [markdown]
# Честно говоря, ничего не понятно. Посчитаем качество:

# %%
def decoding_accuracy(real_text, decoded_text):
    return sum([1 if r == d else 0 for r, d in zip(real_text, decoded_text)]) / len(real_text)

# %%
print(f"Точность декодирования: {decoding_accuracy(anna_karenina, anna_karenina_decoded)}")
# Out:
# Точность декодирования: 0.34292035398230086

# %% [markdown]
# Точность получилась достаточно низкой на небольшом куске

# %% [markdown]
# ## Часть 2

# %% [markdown]
# Вряд ли в результате получилась такая уж хорошая расшифровка, разве что если вы брали в качестве тестовых данных целые рассказы. Но и Шерлок Холмс был не так уж прост: после буквы E, которая действительно выделяется частотой, дальше он анализировал уже конкретные слова и пытался угадать, какими они могли бы быть. Я не знаю, как запрограммировать такой интуитивный анализ, так что давайте просто сделаем следующий логический шаг: <br>
# - подсчитайте частоты биграмм (т.е. пар последовательных букв) по корпусам;
# - проведите тестирование аналогично п.1, но при помощи биграмм.

# %% [markdown]
# 1. Подсчитаем частоты биграмм:

# %%
def count_ngram_freqs(text, n_gram=2):
    freqs = defaultdict(int)
    for start in range(len(text)):
        part = text[start:start + n_gram]
        if len(part) != n_gram:
            break
        freqs[part] += 1
    sum_freqs = sum(freqs.values())
    freqs = {n_g: v / sum_freqs for n_g, v in sorted(freqs.items(), key=lambda x: x[1], reverse=True)}
    return freqs

# %%
bi_grams_freqs = count_ngram_freqs(war_and_peace)

# %% [markdown]
# 2. Аналогичные действия:

# %%
bigrams_encoding = list(bi_grams_freqs.keys())
np.random.shuffle(bigrams_encoding)

# %%
bigrams_mapping, bigrams_inverse_mapping = get_mappings(bi_grams_freqs.keys(), bigrams_encoding)

# %%
def map_to_ngrams(text, mapping, n_gram=2):
    new_text = []
    for start in range(0, len(text), n_gram):
        part = text[start: start + n_gram]
        if len(part) != n_gram:
            new_text.append(np.random.choice(list(mapping.values()))[:len(part)])
        else:
            try:
                new_text.append(mapping[part])
            except Exception:
                new_text.append(np.random.choice(list(mapping.values())))
    new_text = "".join(new_text)
    assert len(new_text) == len(text)
    return new_text

# %%
anna_karenina_bigram_encoded = map_to_ngrams(anna_karenina, bigrams_mapping)

# %%
anna_karenina_bigram_encoded
# Out:
# 'gorkxxdstfrryfjiuznxssrjgvuzhcingedek hukppfcya baingerrxkwrttznaiiswerkmtinttdqodwro xahbzngiktekuplmtfdeuzhbjircrbfdwrapodajibmiunezviuwrrxbcywmlsvjuzczlravevbukthcingecqibvoorjehbznhzwrttznhbdmkftgznplcyrkcyrjofduinttdqhzwrnxkdzndmdqlrdeuzfrqutfjiuzodwrc mrcya barrwnezdsugodbokmimwngvuzbcajgknpnkcywmsmbmxiyfgyznodmiwrgfpfajdusm pdeihjeodwro xahbznhbznapopingedkuqavktgudqmkcfodwrmrucrkktbcingecqibvoorjehbznxbrjyaphznklmikmnpsskdgrzehuisgvrjdeetwn'

# %%
new_encoding_bigram_freqs = count_ngram_freqs(anna_karenina_encoded)

# %%
bi_grams_freqs
# Out:
# {'e ': 0.03306911218938314,
#  ' t': 0.026475838339726592,
#  'he': 0.024709513208540597,
#  'th': 0.024331366664937872,
#  'd ': 0.02280171137571157,
#  ' a': 0.021054096620380918,
#  's ': 0.018668359572720665,
#  't ': 0.01761302872403771,
#  'in': 0.015905460738081655,
#  ' h': 0.015126846500732987,
#  'an': 0.01502476006404857,
#  'er': 0.014657445843309466,
#  ' s': 0.01214730120882158,
#  'n ': 0.012126621319718306,
#  ' w': 0.012073116209816185,
#  're': 0.01173994021870788,
#  'nd': 0.011384114825248372,
#  ' o': 0.010427916143377939,
#  'ed': 0.009562643323120313,
#  'r ': 0.009327286489992575,
#  'at': 0.009280018172042234,
#  'y ': 0.009272468371258499,
#  ' i': 0.009204520164204885,
#  'ha': 0.00916020611612644,
#  'on': 0.009122128859999776,
#  'en': 0.008818495567610435,
#  'hi': 0.008552939531347758,
#  'ng': 0.008221733053487385,
#  'to': 0.008207289956335892,
#  'o ': 0.008162647656049458,
#  'ou': 0.007737232794496392,
#  ' b': 0.00744672959042659,
#  'is': 0.0072317243941941375,
#  'it': 0.007071537316695761,
#  'as': 0.007009825901593927,
#  'es': 0.007006215127306054,
#  'g ': 0.0066287250881193055,
#  'or': 0.006527951660266843,
#  ' f': 0.006387787967455763,
#  'te': 0.006324107039105999,
#  'st': 0.00607594836986671,
#  ' c': 0.0059922440568296485,
#  'ar': 0.005911822265872471,
#  'f ': 0.00585175211181058,
#  'nt': 0.0058415762933629375,
#  ' m': 0.005828117952835409,
#  'se': 0.0058248354307555246,
#  'le': 0.005634449150122209,
#  'of': 0.005574378996060317,
#  ' p': 0.005376771166851254,
#  ' d': 0.005047205950030823,
#  'me': 0.004990746570256805,
#  'ne': 0.004908355266051697,
#  'ro': 0.00490343148293187,
#  've': 0.004789856218967857,
#  'ea': 0.004736679361273723,
#  'ti': 0.004697945600731083,
#  'al': 0.004694006574235222,
#  'h ': 0.004642142725373042,
#  'de': 0.0045712402484475315,
#  'ho': 0.004522002417249259,
#  'ri': 0.004503292041393917,
#  'a ': 0.004499681267106043,
#  ' r': 0.00445306945357168,
#  ' n': 0.004396281821589673,
#  'll': 0.004345402729351459,
#  'ce': 0.0043175012916724384,
#  'no': 0.004224277664603711,
#  'co': 0.0042141018461560684,
#  'wa': 0.004022074304482809,
#  ' l': 0.003965614924708791,
#  'wh': 0.003933774460533909,
#  'l ': 0.0038717347932240866,
#  'ch': 0.00381067988253823,
#  'ad': 0.0037430599276926037,
#  'be': 0.0037394491534047305,
#  'sh': 0.003675768225054966,
#  'om': 0.003664935902191346,
#  'ut': 0.003624232628400775,
#  'm ': 0.003609789531249282,
#  'el': 0.0035237874527563008,
#  ' e': 0.0034305638256875736,
#  'ot': 0.003384936768777175,
#  'ss': 0.003335042433162927,
#  'wi': 0.0033061562388599407,
#  'ow': 0.0032966369248282746,
#  'ly': 0.003291713141708448,
#  'im': 0.003268735487149254,
#  'si': 0.0032001307756796627,
#  'ma': 0.0031620535195529993,
#  'li': 0.0031443279003216217,
#  'nc': 0.0030770361976839838,
#  'ta': 0.003075066684436053,
#  'so': 0.0030639061093644445,
#  'sa': 0.0030104009994623227,
#  'us': 0.002939170270328823,
#  'rs': 0.002914879606937676,
#  ' g': 0.0029112688326498027,
#  'ai': 0.002891573700170494,
#  'un': 0.0028850086560107246,
#  'ic': 0.0028840238993867594,
#  'et': 0.002880413125098886,
#  'ra': 0.0028702373066512433,
#  'id': 0.0028567789661237157,
#  'pe': 0.002782922219326308,
#  'il': 0.002781937462702343,
#  'ie': 0.0027770136795825157,
#  'ee': 0.0027701203832147577,
#  'lo': 0.00275666204268723,
#  'fo': 0.002679522773809938,
#  'di': 0.00267689675614603,
#  'ur': 0.002667049189906376,
#  'pr': 0.002580390606997418,
#  'la': 0.0025689017797178213,
#  'ol': 0.002566604014261902,
#  'we': 0.0025495348994465012,
#  'em': 0.0024783041703130017,
#  'w ': 0.002472395630569209,
#  'io': 0.002452372245881912,
#  'oo': 0.0023909890829880666,
#  'ac': 0.002352911826861403,
#  'ns': 0.002287917889679685,
#  'ld': 0.0022839788631838233,
#  'os': 0.0022761008101920997,
#  'ov': 0.002265924991744457,
#  'mo': 0.0022271912312018167,
#  'ca': 0.0022104503685944042,
#  'ni': 0.0021198527591895847,
#  'ul': 0.0020880122950147025,
#  'ec': 0.00203253767186465,
#  'gh': 0.0020194075835451106,
#  'yo': 0.002011857782761376,
#  'na': 0.001961963447147127,
#  'ir': 0.001950802872075519,
#  'ge': 0.0019465355933716687,
#  ' y': 0.0019307794873882219,
#  'ry': 0.0019071453284130516,
#  'tr': 0.0018999237798373052,
#  'fr': 0.001878587386318054,
#  'ke': 0.0018638160369585726,
#  'ev': 0.0018365711036955291,
#  'do': 0.0018185172322561628,
#  'ay': 0.0017879897769132345,
#  'bu': 0.0017328434059711703,
#  'mi': 0.001696079158676461,
#  'ts': 0.0016944378976365185,
#  ' u': 0.0016842620791888757,
#  'tt': 0.0016780252872370947,
#  'rt': 0.0016586584069657744,
#  'rr': 0.001641261039942385,
#  'vi': 0.0016064663058956066,
#  'pa': 0.001571015067432851,
#  'po': 0.0015683890497689432,
#  'fi': 0.0015598544923612428,
#  'ap': 0.001557884979113312,
#  'am': 0.0015546024570334271,
#  'fe': 0.0015299835414342914,
#  'i ': 0.001528998784810326,
#  'wo': 0.0015194794707786602,
#  'k ': 0.0015119296699949252,
#  'av': 0.0014873107543957895,
#  'rd': 0.0014666308652925154,
#  'ht': 0.0014459509761892413,
#  'ig': 0.0014114844943504512,
#  'pl': 0.0013875220831672925,
#  'pi': 0.0013842395610874077,
#  'ct': 0.0013586358888643063,
#  'bo': 0.0013461623049607443,
#  'ew': 0.001328108433521378,
#  'su': 0.0013189173716977008,
#  'fa': 0.0013179326150737354,
#  'ep': 0.0013067720400021271,
#  'ei': 0.0013034895179222423,
#  'ey': 0.0012969244737624727,
#  'if': 0.001235213058660639,
#  'dr': 0.0012302892755408118,
#  'tu': 0.0012112506474774804,
#  'ef': 0.001201403081237826,
#  'bl': 0.001193196776038114,
#  ' v': 0.0011922120194141487,
#  'ga': 0.0011895860017502409,
#  ' k': 0.0011886012451262752,
#  'ag': 0.0011754711568067362,
#  'u ': 0.0011689061126469668,
#  'ab': 0.0011606998074472547,
#  'sp': 0.001158730294199324,
#  'iv': 0.0011567607809513931,
#  'mp': 0.0011544630154954737,
#  'ki': 0.001127874586648407,
#  'ok': 0.0011272180822324302,
#  'ug': 0.001079621512074101,
#  'go': 0.0010579568663468615,
#  'ty': 0.0010553308486829537,
#  'ba': 0.0010540178398509997,
#  'od': 0.0010376052294515758,
#  'op': 0.0010372769772435874,
#  'da': 0.001036292220619622,
#  'ex': 0.001028742419835887,
#  'tl': 0.0010198796102201982,
#  'rm': 0.0010057647652766937,
#  'ru': 0.001004780008652728,
#  'ia': 0.0009758938143497422,
#  'ds': 0.0009479923766707217,
#  'ff': 0.0009460228634227908,
#  'p ': 0.0009309232618553209,
#  'gr': 0.000922716956655609,
#  'up': 0.0009177931735357817,
#  'ye': 0.0008761051431212452,
#  'rn': 0.0008734791254573374,
#  'pp': 0.0008656010724656139,
#  'ck': 0.0008613337937617637,
#  'gi': 0.0008590360283058444,
#  'ak': 0.0008498449664821671,
#  'ci': 0.0008462341921942938,
#  'by': 0.0008373713825786049,
#  'sc': 0.0008314628428348123,
#  'ft': 0.000829165077378893,
#  'au': 0.0008278520685469391,
#  'my': 0.0008242412942590659,
#  'eg': 0.000778942489556656,
#  'lf': 0.0007710644365649325,
#  'qu': 0.000764499392405163,
#  'oi': 0.0007562930872054511,
#  'aw': 0.0007405369812220042,
#  'wn': 0.0007398804768060272,
#  'pt': 0.0007323306760222923,
#  'v ': 0.0007320024238143038,
#  'nl': 0.0007306894149823499,
#  'sk': 0.0007208418487426955,
#  'ny': 0.000708040012631145,
#  'eo': 0.0006978641941835021,
#  'kn': 0.0006847341058639631,
#  'cr': 0.000679810322744136,
#  'uc': 0.0006784973139121821,
#  'nn': 0.0006722605219604009,
#  'cl': 0.0006584739292248849,
#  'ms': 0.0006581456770168965,
#  'br': 0.0006492828674012076,
#  'ue': 0.0006266334650500027,
#  'va': 0.0006233509429701178,
#  'sm': 0.0006210531775141985,
#  'fu': 0.0006167858988103483,
#  'lt': 0.0006046405671147747,
#  'ys': 0.0005895409655473047,
#  'ui': 0.0005819911647635698,
#  'af': 0.0005731283551478809,
#  'ls': 0.00057115884189995,
#  'ya': 0.0005698458330679961,
#  'cu': 0.0005550744837085147,
#  'mu': 0.0005517919616286299,
#  'rc': 0.0005304555681093789,
#  'hu': 0.0005301273159013904,
#  'tw': 0.0005150277143339205,
#  'oc': 0.0005124016966700127,
#  'oa': 0.0005101039312140933,
#  'dd': 0.0005058366525102431,
#  'lu': 0.0005012411215984044,
#  'vo': 0.0004979585995185196,
#  'nk': 0.0004979585995185196,
#  'gl': 0.0004976303473105312,
#  ' j': 0.0004851567634069691,
#  'ud': 0.0004749809449593263,
#  'rg': 0.0004746526927513378,
#  'mm': 0.0004684159007995567,
#  'dl': 0.00045988134339185633,
#  'eh': 0.00045627056910398306,
#  'um': 0.0004533162992320868,
#  'gu': 0.00044806426390427113,
#  'xp': 0.0004477360116962827,
#  'ib': 0.0004474077594882942,
#  'ua': 0.0004441252374084094,
#  'sl': 0.00044215572416047856,
#  'rl': 0.00043821669766461684,
#  'yi': 0.000436247184416686,
#  'hr': 0.0004346059233767436,
#  'ik': 0.00043197990571283576,
#  'dy': 0.0004224605916811699,
#  ' q': 0.00041688030414536585,
#  'yt': 0.00040933050336163087,
#  'fl': 0.0004060479812817461,
#  'sw': 0.00039226138854623005,
#  'du': 0.0003899636230903107,
#  'ju': 0.00038832236205036834,
#  'pu': 0.0003843833355545066,
#  'mb': 0.00038372683113852967,
#  'ps': 0.00035779490670743996,
#  'lk': 0.0003489320970917511,
#  'cc': 0.0003472908360518087,
#  'nf': 0.0003430235573479585,
#  'dt': 0.00034236705293198155,
#  'gs': 0.000336458513188189,
#  'bi': 0.0003354737565642235,
#  'ob': 0.00033251948669232726,
#  'nu': 0.0003298934690284194,
#  'gn': 0.0003298934690284194,
#  'rk': 0.0003115113453810647,
#  'hy': 0.00030363329238934124,
#  'ub': 0.00030363329238934124,
#  'ws': 0.0002993660136854911,
#  'ip': 0.0002859076731579635,
#  'tc': 0.00028360990770204416,
#  'kh': 0.00028098389003813635,
#  'og': 0.00026654079288664334,
#  'ks': 0.0002612887575588277,
#  'oy': 0.0002534107045671043,
#  'nv': 0.0002534107045671043,
#  'eb': 0.0002501281824872195,
#  'sb': 0.00024257838170348454,
#  'ze': 0.00024060886845555366,
#  'rv': 0.00023929585962359975,
#  'jo': 0.00023502858091974956,
#  'rp': 0.00023240256325584175,
#  'ku': 0.0002228832492241759,
#  'dn': 0.00022124198818423353,
#  'ka': 0.0002173029616883718,
#  'xc': 0.00021664645727239483,
#  'sn': 0.00021402043960848702,
#  'zo': 0.00020844015207268293,
#  'vs': 0.00020712714324072902,
#  'ko': 0.00020450112557682118,
#  'uz': 0.00020121860349693642,
#  'dh': 0.00020089035128894795,
#  'iz': 0.00019498181154515535,
#  'rf': 0.00019465355933716687,
#  'sf': 0.00019071453284130515,
#  'gt': 0.0001874320107614204,
#  'oh': 0.00018710375855343191,
#  'je': 0.00018546249751348953,
#  'oe': 0.00018414948868153563,
#  'vn': 0.00018053871439366236,
#  'wr': 0.00017955395776969693,
#  'lw': 0.00017791269672975455,
#  'rw': 0.00017528667906584674,
#  'c ': 0.00017495842685785827,
#  'dg': 0.00017397367023389284,
#  'xi': 0.00016937813932205414,
#  'dm': 0.00016806513049010024,
#  'lr': 0.00016478260841021547,
#  'ii': 0.0001631413473702731,
#  'xt': 0.00015985882529038833,
#  'bs': 0.00015788931204245744,
#  'tm': 0.0001559197987945266,
#  'gg': 0.00015526329437854963,
#  'rh': 0.00015230902450665335,
#  'sy': 0.00014935475463475706,
#  'dw': 0.00014836999801079163,
#  'db': 0.00014804174580280316,
#  ' x': 0.00014771349359481465,
#  'lp': 0.00014607223255487227,
#  'ph': 0.00014475922372291837,
#  'lv': 0.00014377446709895294,
#  'lm': 0.00014344621489096446,
#  'nh': 0.00014114844943504513,
#  'eu': 0.00013589641410722948,
#  'hm': 0.00013589641410722948,
#  'nw': 0.00013228563981935624,
#  'az': 0.00012637710007556367,
#  'wd': 0.00012637710007556367,
#  'ah': 0.0001260488478675752,
#  'ek': 0.00012145331695573651,
#  'rb': 0.00011849904708384021,
#  'yw': 0.0001158730294199324,
#  'kl': 0.00011423176837999,
#  'xa': 0.00011390351617200153,
#  'dv': 0.00011324701175602457,
#  'py': 0.00011127749850809372,
#  'yb': 0.00011094924630010524,
#  'uf': 0.00011062099409211676,
#  'tf': 0.00010930798526016285,
#  'dp': 0.00010897973305217437,
#  'mt': 0.00010733847201223199,
#  'ix': 0.00010635371538826656,
#  'tn': 0.00010602546318027808,
#  'yc': 0.00010504070655631265,
#  'fs': 0.00010405594993234723,
#  'xe': 0.00010339944551637026,
#  'df': 0.00010307119330838178,
#  'nb': 0.00010241468889240483,
#  'cy': 0.00010175818447642788,
#  'eq': 9.847566239654312e-05,
#  'yl': 9.71626535645892e-05,
#  'sd': 9.71626535645892e-05,
#  'hs': 9.519314031665834e-05,
#  'mn': 9.519314031665834e-05,
#  'dc': 9.125411382079661e-05,
#  'np': 9.125411382079661e-05,
#  'dj': 8.764333953292337e-05,
#  'uk': 8.600207849298099e-05,
#  'yf': 8.600207849298099e-05,
#  'bt': 8.534557407700402e-05,
#  'ym': 8.337606082907317e-05,
#  'tp': 8.304780862108469e-05,
#  'nq': 8.206305199711926e-05,
#  'zi': 8.107829537315383e-05,
#  'nm': 7.976528654119991e-05,
#  'tb': 7.910878212522296e-05,
#  'bb': 7.615451225332667e-05,
#  'yh': 7.549800783734972e-05,
#  'x ': 7.516975562936124e-05,
#  'vl': 7.123072913349952e-05,
#  'wl': 6.926121588556866e-05,
#  'yp': 6.696345042964931e-05,
#  'ez': 6.368092834976455e-05,
#  'sr': 6.335267614177607e-05,
#  'yr': 6.335267614177607e-05,
#  'sq': 6.269617172579912e-05,
#  'ml': 6.105491068585672e-05,
#  'nr': 6.0070154061891295e-05,
#  'fh': 5.941364964591434e-05,
#  'ae': 5.9085397437925866e-05,
#  'hl': 5.777238860597196e-05,
#  'aj': 5.744413639798348e-05,
#  'sg': 5.744413639798348e-05,
#  'bj': 5.744413639798348e-05,
#  'mf': 5.645937977401805e-05,
#  'td': 5.613112756602957e-05,
#  'gw': 5.5146370942064144e-05,
#  'b ': 5.383336211011023e-05,
#  'xx': 5.1863848862179375e-05,
#  'xv': 5.153559665419089e-05,
#  'uo': 5.153559665419089e-05,
#  'yd': 5.1207344446202415e-05,
#  'yn': 5.087909223821394e-05,
#  'zh': 5.087909223821394e-05,
#  'ln': 4.9566083406260034e-05,
#  'hn': 4.9566083406260034e-05,
#  'mw': 4.923783119827156e-05,
#  'hh': 4.7924822366317646e-05,
#  'ox': 4.6283561326375264e-05,
#  'pc': 4.6283561326375264e-05,
#  'za': 4.5627056910398305e-05,
#  'tz': 4.529880470240983e-05,
#  'lc': 4.497055249442135e-05,
#  'iu': 4.4642300286432876e-05,
#  'wt': 4.4642300286432876e-05,
#  'hw': 4.43140480784444e-05,
#  'zu': 4.3001039246490495e-05,
#  'nj': 4.3001039246490495e-05,
#  'lb': 4.267278703850201e-05,
#  'oj': 4.2344534830513535e-05,
#  ' z': 4.2344534830513535e-05,
#  'lg': 4.0703273790571154e-05,
#  'uv': 4.037502158258268e-05,
#  'kw': 4.00467693745942e-05,
#  'sv': 3.971851716660572e-05,
#  'hd': 3.939026495861724e-05,
#  'fc': 3.939026495861724e-05,
#  'mh': 3.939026495861724e-05,
#  'oz': 3.9062012750628766e-05,
#  'z ': 3.873376054264029e-05,
#  'cq': 3.840550833465181e-05,
#  'mr': 3.840550833465181e-05,
#  'gy': 3.774900391867486e-05,
#  'vy': 3.774900391867486e-05,
#  'ky': 3.7420751710686384e-05,
#  'hc': 3.709249950269791e-05,
#  'dk': 3.709249950269791e-05,
#  'cs': 3.6764247294709425e-05,
#  'pf': 3.5779490670743996e-05,
#  'ej': 3.545123846275552e-05,
#  'gd': 3.5122986254767044e-05,
#  'kr': 3.446648183879009e-05,
#  'hk': 3.4138229630801615e-05,
#  'fy': 3.380997742281313e-05,
#  'hf': 3.3481725214824655e-05,
#  'fw': 3.3481725214824655e-05,
#  'ja': 3.2496968590859227e-05,
#  'mc': 3.2496968590859227e-05,
#  'tg': 3.2496968590859227e-05,
#  'hb': 3.1840464174882274e-05,
#  'vr': 3.1840464174882274e-05,
#  'ww': 3.085570755091684e-05,
#  'fp': 2.987095092695141e-05,
#  'fb': 2.987095092695141e-05,
#  'gp': 2.9542698718962933e-05,
#  'gb': 2.888619430298598e-05,
#  'yu': 2.85579420949975e-05,
#  'wf': 2.7573185471032072e-05,
#  'nx': 2.6916681055055116e-05,
#  'rz': 2.6916681055055116e-05,
#  'vc': 2.6260176639078164e-05,
#  'lh': 2.6260176639078164e-05,
#  'vw': 2.461891559913578e-05,
#  'hp': 2.3962411183158823e-05,
#  'gf': 2.330590676718187e-05,
#  'gm': 2.2649402351204914e-05,
#  'wk': 2.2649402351204914e-05,
#  'kt': 2.2649402351204914e-05,
#  'aa': 2.2649402351204914e-05,
#  'bm': 2.2649402351204914e-05,
#  'gc': 2.2321150143216438e-05,
#  'kc': 2.2321150143216438e-05,
#  'fm': 2.2321150143216438e-05,
#  'yg': 2.1992897935227962e-05,
#  'uh': 2.1992897935227962e-05,
#  'dq': 2.1664645727239485e-05,
#  'yy': 2.100814131126253e-05,
#  'ao': 2.100814131126253e-05,
#  'xh': 2.100814131126253e-05,
#  'zm': 2.100814131126253e-05,
#  'iw': 2.0679889103274053e-05,
#  'tk': 2.0679889103274053e-05,
#  'pw': 2.0351636895285577e-05,
#  'yk': 1.9366880271320145e-05,
#  'wy': 1.9366880271320145e-05,
#  'wc': 1.903862806333167e-05,
#  'ax': 1.6740862607412328e-05,
#  'vt': 1.6740862607412328e-05,
#  'bv': 1.542785377545842e-05,
#  'tv': 1.542785377545842e-05,
#  'zz': 1.542785377545842e-05,
#  'fn': 1.5099601567469943e-05,
#  'fd': 1.4771349359481467e-05,
#  'ux': 1.4114844943504512e-05,
#  'zl': 1.4114844943504512e-05,
#  'yv': 1.3130088319539082e-05,
#  'md': 1.2801836111550604e-05,
#  'ih': 1.2801836111550604e-05,
#  'km': 1.2473583903562128e-05,
#  'wb': 1.214533169557365e-05,
#  'kf': 1.214533169557365e-05,
#  'wp': 1.1817079487585173e-05,
#  'wu': 1.1488827279596697e-05,
#  'hg': 1.0504070655631265e-05,
#  'oq': 1.0175818447642788e-05,
#  'kb': 1.0175818447642788e-05,
#  'uy': 1.0175818447642788e-05,
#  'pm': 9.519314031665834e-06,
#  'sj': 9.519314031665834e-06,
#  'zd': 9.519314031665834e-06,
#  'pb': 9.191061823677356e-06,
#  'iq': 9.191061823677356e-06,
#  'pn': 9.191061823677356e-06,
#  'fg': 8.86280961568888e-06,
#  'wm': 8.86280961568888e-06,
#  'kp': 8.206305199711926e-06,
#  'lz': 8.206305199711926e-06,
#  'vu': 7.87805299172345e-06,
#  'nz': 7.5498007837349714e-06,
#  'vd': 7.5498007837349714e-06,
#  'fk': 7.221548575746495e-06,
#  'pk': 6.893296367758018e-06,
#  'mg': 6.893296367758018e-06,
#  'uw': 6.893296367758018e-06,
#  'vh': 6.893296367758018e-06,
#  'bw': 6.893296367758018e-06,
#  'rq': 6.236791951781064e-06,
#  'vb': 5.908539743792587e-06,
#  'bd': 5.908539743792587e-06,
#  'kg': 5.908539743792587e-06,
#  'xu': 5.908539743792587e-06,
#  'wg': 5.5802875358041095e-06,
#  'hv': 5.5802875358041095e-06,
#  'zn': 5.5802875358041095e-06,
#  'tj': 4.923783119827155e-06,
#  'cw': 4.923783119827155e-06,
#  'kv': 4.923783119827155e-06,
#  'zy': 4.595530911838678e-06,
#  'rj': 4.595530911838678e-06,
#  'xo': 4.595530911838678e-06,
#  'bn': 4.267278703850202e-06,
#  'kd': 4.267278703850202e-06,
#  'gv': 4.267278703850202e-06,
#  'mk': 4.267278703850202e-06,
#  'yj': 3.939026495861725e-06,
#  'aq': 3.939026495861725e-06,
#  'yz': 3.939026495861725e-06,
#  'pg': 3.939026495861725e-06,
#  'mv': 3.6107742878732476e-06,
#  'ji': 3.6107742878732476e-06,
#  'fv': 3.6107742878732476e-06,
#  'vg': 3.6107742878732476e-06,
#  'vp': 3.6107742878732476e-06,
#  'cd': 3.2825220798847704e-06,
#  'tq': 3.2825220798847704e-06,
#  'gj': 3.2825220798847704e-06,
#  'xs': 3.2825220798847704e-06,
#  'vk': 3.2825220798847704e-06,
#  'yq': 2.9542698718962933e-06,
#  'gk': 2.9542698718962933e-06,
#  'hj': 2.626017663907816e-06,
#  'vm': 2.626017663907816e-06,
#  'lq': 2.626017663907816e-06,
#  'sz': 2.626017663907816e-06,
#  'pd': 1.9695132479308624e-06,
#  'xb': 1.9695132479308624e-06,
#  'xf': 1.9695132479308624e-06,
#  'wv': 1.9695132479308624e-06,
#  'dz': 1.9695132479308624e-06,
#  'gq': 1.9695132479308624e-06,
#  'cm': 1.9695132479308624e-06,
#  'xy': 1.9695132479308624e-06,
#  'gz': 1.9695132479308624e-06,
#  'bc': 1.6412610399423852e-06,
#  'cz': 1.6412610399423852e-06,
#  'vf': 1.6412610399423852e-06,
#  'fj': 1.6412610399423852e-06,
#  'xm': 1.6412610399423852e-06,
#  'vv': 1.313008831953908e-06,
#  'iy': 1.313008831953908e-06,
#  'xq': 1.313008831953908e-06,
#  'xl': 1.313008831953908e-06,
#  'bh': 1.313008831953908e-06,
#  'zk': 1.313008831953908e-06,
#  'cp': 1.313008831953908e-06,
#  'xn': 1.313008831953908e-06,
#  'uu': 1.313008831953908e-06,
#  'xw': 1.313008831953908e-06,
#  'vj': 9.847566239654312e-07,
#  'ij': 9.847566239654312e-07,
#  'zv': 9.847566239654312e-07,
#  'uj': 9.847566239654312e-07,
#  'cb': 9.847566239654312e-07,
#  'mj': 9.847566239654312e-07,
#  'xr': 9.847566239654312e-07,
#  'pj': 9.847566239654312e-07,
#  'cf': 9.847566239654312e-07,
#  'cg': 9.847566239654312e-07,
#  'kj': 6.56504415976954e-07,
#  'wq': 6.56504415976954e-07,
#  'zw': 6.56504415976954e-07,
#  'pv': 6.56504415976954e-07,
#  'zc': 6.56504415976954e-07,
#  'uq': 6.56504415976954e-07,
#  'fq': 6.56504415976954e-07,
#  'xd': 6.56504415976954e-07,
#  'mq': 6.56504415976954e-07,
#  'kk': 6.56504415976954e-07,
#  'zs': 6.56504415976954e-07,
#  'zb': 3.28252207988477e-07,
#  'wj': 3.28252207988477e-07,
#  'cn': 3.28252207988477e-07,
#  'zp': 3.28252207988477e-07,
#  'hz': 3.28252207988477e-07,
#  'q ': 3.28252207988477e-07,
#  'kz': 3.28252207988477e-07,
#  'xk': 3.28252207988477e-07,
#  'kq': 3.28252207988477e-07,
#  'zt': 3.28252207988477e-07,
#  'tx': 3.28252207988477e-07}

# %%
new_encoding_bigram_freqs
# Out:
# {'f ': 0.03547671840354767,
#  'dn': 0.03547671840354767,
#  'qn': 0.03547671840354767,
#  'nf': 0.031042128603104215,
#  ' d': 0.026607538802660754,
#  'n ': 0.026607538802660754,
#  'sn': 0.022172949002217297,
#  'xn': 0.022172949002217297,
#  'ni': 0.022172949002217297,
#  'wx': 0.019955654101995565,
#  'ix': 0.019955654101995565,
#  'nj': 0.017738359201773836,
#  'mx': 0.017738359201773836,
#  'ts': 0.017738359201773836,
#  'nm': 0.015521064301552107,
#  'xq': 0.015521064301552107,
#  'dg': 0.013303769401330377,
#  'nw': 0.013303769401330377,
#  'mt': 0.013303769401330377,
#  ' i': 0.013303769401330377,
#  ' m': 0.011086474501108648,
#  'fn': 0.011086474501108648,
#  'zd': 0.008869179600886918,
#  'np': 0.008869179600886918,
#  'pm': 0.008869179600886918,
#  'sd': 0.008869179600886918,
#  'jw': 0.008869179600886918,
#  'iq': 0.008869179600886918,
#  'gd': 0.008869179600886918,
#  'wf': 0.008869179600886918,
#  'wg': 0.008869179600886918,
#  'eb': 0.008869179600886918,
#  'bn': 0.008869179600886918,
#  'xm': 0.008869179600886918,
#  ' w': 0.0066518847006651885,
#  'xu': 0.0066518847006651885,
#  'un': 0.0066518847006651885,
#  'is': 0.0066518847006651885,
#  'wm': 0.0066518847006651885,
#  'dq': 0.0066518847006651885,
#  ' t': 0.0066518847006651885,
#  'sl': 0.0066518847006651885,
#  'li': 0.0066518847006651885,
#  ' n': 0.0066518847006651885,
#  'no': 0.0066518847006651885,
#  'nu': 0.0066518847006651885,
#  'mn': 0.0066518847006651885,
#  'gn': 0.0066518847006651885,
#  'oi': 0.0066518847006651885,
#  'ic': 0.0066518847006651885,
#  'ns': 0.0066518847006651885,
#  'nx': 0.0066518847006651885,
#  'mo': 0.0066518847006651885,
#  'on': 0.0066518847006651885,
#  'gb': 0.004434589800443459,
#  'ji': 0.004434589800443459,
#  'xo': 0.004434589800443459,
#  'ot': 0.004434589800443459,
#  'sw': 0.004434589800443459,
#  'xs': 0.004434589800443459,
#  'bs': 0.004434589800443459,
#  'wo': 0.004434589800443459,
#  'od': 0.004434589800443459,
#  'nq': 0.004434589800443459,
#  'ws': 0.004434589800443459,
#  'sp': 0.004434589800443459,
#  'mz': 0.004434589800443459,
#  'if': 0.004434589800443459,
#  'in': 0.004434589800443459,
#  'dx': 0.004434589800443459,
#  'xp': 0.004434589800443459,
#  'en': 0.004434589800443459,
#  'nl': 0.004434589800443459,
#  'ld': 0.004434589800443459,
#  'dd': 0.004434589800443459,
#  'um': 0.004434589800443459,
#  'ds': 0.004434589800443459,
#  'dw': 0.004434589800443459,
#  'cw': 0.004434589800443459,
#  'we': 0.004434589800443459,
#  's ': 0.004434589800443459,
#  'te': 0.004434589800443459,
#  'eq': 0.004434589800443459,
#  'mf': 0.004434589800443459,
#  'ne': 0.004434589800443459,
#  'cd': 0.004434589800443459,
#  'ny': 0.004434589800443459,
#  'iw': 0.004434589800443459,
#  'gs': 0.004434589800443459,
#  'dc': 0.004434589800443459,
#  'ee': 0.004434589800443459,
#  'dz': 0.0022172949002217295,
#  'bf': 0.0022172949002217295,
#  'ml': 0.0022172949002217295,
#  'le': 0.0022172949002217295,
#  'em': 0.0022172949002217295,
#  'sv': 0.0022172949002217295,
#  'vb': 0.0022172949002217295,
#  'qw': 0.0022172949002217295,
#  'pi': 0.0022172949002217295,
#  'ig': 0.0022172949002217295,
#  'gg': 0.0022172949002217295,
#  'bw': 0.0022172949002217295,
#  'xf': 0.0022172949002217295,
#  'fg': 0.0022172949002217295,
#  'gw': 0.0022172949002217295,
#  'wu': 0.0022172949002217295,
#  'ut': 0.0022172949002217295,
#  'td': 0.0022172949002217295,
#  'og': 0.0022172949002217295,
#  'p ': 0.0022172949002217295,
#  'uw': 0.0022172949002217295,
#  'ge': 0.0022172949002217295,
#  'j ': 0.0022172949002217295,
#  'gx': 0.0022172949002217295,
#  'xd': 0.0022172949002217295,
#  'ss': 0.0022172949002217295,
#  'xx': 0.0022172949002217295,
#  'tx': 0.0022172949002217295,
#  'pd': 0.0022172949002217295,
#  'fm': 0.0022172949002217295,
#  'ew': 0.0022172949002217295,
#  'wz': 0.0022172949002217295,
#  'zw': 0.0022172949002217295,
#  'si': 0.0022172949002217295,
#  'wc': 0.0022172949002217295,
#  'cn': 0.0022172949002217295,
#  'ym': 0.0022172949002217295,
#  'ms': 0.0022172949002217295,
#  'fw': 0.0022172949002217295,
#  'io': 0.0022172949002217295,
#  'oo': 0.0022172949002217295,
#  'mj': 0.0022172949002217295,
#  'jn': 0.0022172949002217295,
#  'ei': 0.0022172949002217295,
#  'sf': 0.0022172949002217295,
#  'fd': 0.0022172949002217295,
#  ' g': 0.0022172949002217295,
#  'qi': 0.0022172949002217295,
#  'ib': 0.0022172949002217295,
#  'xe': 0.0022172949002217295,
#  'cs': 0.0022172949002217295,
#  'de': 0.0022172949002217295,
#  'ez': 0.0022172949002217295,
#  'lt': 0.0022172949002217295,
#  'tf': 0.0022172949002217295,
#  'ie': 0.0022172949002217295,
#  'nc': 0.0022172949002217295,
#  'cl': 0.0022172949002217295,
#  'd ': 0.0022172949002217295,
#  'me': 0.0022172949002217295,
#  'jd': 0.0022172949002217295,
#  'yi': 0.0022172949002217295,
#  'pw': 0.0022172949002217295}

# %%
def decode_ngram(text, real_freqs, freqs, n_gram=2):
    assert len(real_freqs) != len(freqs)
    
    real_freqs = list(sorted(real_freqs.items(), key=lambda x: x[1], reverse=True))
    freqs = list(sorted(freqs.items(), key=lambda x: x[1], reverse=True))
    
    real_mapping = {}
    """
    Пусть маппинг первых n символов мы получим из самой частой записи
    """
    for enc_s, real_s in zip(freqs[0], real_freqs[0]):
        real_mapping[enc_s] = real_s
